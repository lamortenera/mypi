# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib nbagg

# %%
import sys
sys.path.append("/home/pi/AIY-voice-kit-python/src")
import aiy._drivers._tts
import aiy.audio

# %%
plt.figure(figsize=(5, 3))
plt.plot([1,2,3])
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
player = aiy.audio.get_player()

# %%
aiy._drivers._tts.say(player, "hi")

# %%
sig, par1, pars = aiy._drivers._tts.say_audio_data("ciao", lang="it-IT")

# %%
player.play_bytes(sig, par1, 2)

# %%
npsig = np.fromstring(sig, 'int16')

# %%
plt.plot(npsig)
#plt.xlim(0, 7000)
# Out:
# <img src="data:image/png;base64,..." width="640">
